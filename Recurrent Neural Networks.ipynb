# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Sample text data
text = "hello"
chars = sorted(list(set(text)))
char_to_int = {c: i for i, c in enumerate(chars)}
int_to_char = {i: c for i, c in enumerate(chars)}

# Prepare the dataset
seq_length = 3
X = []
y = []
for i in range(len(text) - seq_length):
    input_seq = text[i:i + seq_length]
    output_seq = text[i + seq_length]
    X.append([char_to_int[char] for char in input_seq])
    y.append(char_to_int[output_seq])

# Reshape and normalize the data
X = np.reshape(X, (len(X), seq_length, 1))
X = X / float(len(chars))
y = tf.keras.utils.to_categorical(y)

# %%
# Create an RNN model
model = Sequential([
    SimpleRNN(50, input_shape=(X.shape[1], X.shape[2])),
    Dense(y.shape[1], activation='softmax')
])

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50)                2600
#
#  dense (Dense)               (None, 4)                 204
#
# =================================================================
# Total params: 2804 (10.95 KB)
# Trainable params: 2804 (10.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
model.fit(X, y, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 1/1 - 1s - loss: 1.2524 - accuracy: 0.5000 - 1s/epoch - 1s/step
# Epoch 2/200
# 1/1 - 0s - loss: 1.2198 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 3/200
# 1/1 - 0s - loss: 1.1876 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 4/200
# 1/1 - 0s - loss: 1.1558 - accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 5/200
# 1/1 - 0s - loss: 1.1244 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 6/200
# 1/1 - 0s - loss: 1.0934 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 7/200
# 1/1 - 0s - loss: 1.0627 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 8/200
# 1/1 - 0s - loss: 1.0323 - accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 9/200
# 1/1 - 0s - loss: 1.0021 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 10/200
# 1/1 - 0s - loss: 0.9722 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 11/200
# 1/1 - 0s - loss: 0.9425 - accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 12/200
# 1/1 - 0s - loss: 0.9130 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 13/200
# 1/1 - 0s - loss: 0.8837 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 14/200
# 1/1 - 0s - loss: 0.8545 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 15/200
# 1/1 - 0s - loss: 0.8255 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 16/200
# 1/1 - 0s - loss: 0.7967 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 17/200
# 1/1 - 0s - loss: 0.7680 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 18/200
# 1/1 - 0s - loss: 0.7395 - accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 19/200
# 1/1 - 0s - loss: 0.7112 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 20/200
# 1/1 - 0s - loss: 0.6831 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 21/200
# 1/1 - 0s - loss: 0.6553 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 22/200
# 1/1 - 0s - loss: 0.6277 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 23/200
# 1/1 - 0s - loss: 0.6004 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 24/200
# 1/1 - 0s - loss: 0.5734 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 25/200
# 1/1 - 0s - loss: 0.5469 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 26/200
# 1/1 - 0s - loss: 0.5208 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 27/200
# 1/1 - 0s - loss: 0.4952 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 28/200
# 1/1 - 0s - loss: 0.4702 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 29/200
# 1/1 - 0s - loss: 0.4457 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 30/200
# 1/1 - 0s - loss: 0.4220 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 31/200
# 1/1 - 0s - loss: 0.3990 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 32/200
# 1/1 - 0s - loss: 0.3767 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 33/200
# 1/1 - 0s - loss: 0.3553 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 34/200
# 1/1 - 0s - loss: 0.3347 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 35/200
# 1/1 - 0s - loss: 0.3151 - accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 36/200
# 1/1 - 0s - loss: 0.2963 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 37/200
# 1/1 - 0s - loss: 0.2784 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 38/200
# 1/1 - 0s - loss: 0.2615 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 39/200
# 1/1 - 0s - loss: 0.2455 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 40/200
# 1/1 - 0s - loss: 0.2303 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 41/200
# 1/1 - 0s - loss: 0.2161 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 42/200
# 1/1 - 0s - loss: 0.2027 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 43/200
# 1/1 - 0s - loss: 0.1901 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 44/200
# 1/1 - 0s - loss: 0.1783 - accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 45/200
# 1/1 - 0s - loss: 0.1673 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 46/200
# 1/1 - 0s - loss: 0.1569 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 47/200
# 1/1 - 0s - loss: 0.1472 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 48/200
# 1/1 - 0s - loss: 0.1382 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 49/200
# 1/1 - 0s - loss: 0.1298 - accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 50/200
# 1/1 - 0s - loss: 0.1219 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 51/200
# 1/1 - 0s - loss: 0.1146 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 52/200
# 1/1 - 0s - loss: 0.1078 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 53/200
# 1/1 - 0s - loss: 0.1014 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 54/200
# 1/1 - 0s - loss: 0.0955 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 55/200
# 1/1 - 0s - loss: 0.0901 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 56/200
# 1/1 - 0s - loss: 0.0850 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 57/200
# 1/1 - 0s - loss: 0.0802 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 58/200
# 1/1 - 0s - loss: 0.0758 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 59/200
# 1/1 - 0s - loss: 0.0717 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 60/200
# 1/1 - 0s - loss: 0.0679 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 61/200
# 1/1 - 0s - loss: 0.0644 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 62/200
# 1/1 - 0s - loss: 0.0611 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 63/200
# 1/1 - 0s - loss: 0.0580 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 64/200
# 1/1 - 0s - loss: 0.0552 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 65/200
# 1/1 - 0s - loss: 0.0525 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 66/200
# 1/1 - 0s - loss: 0.0500 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 67/200
# 1/1 - 0s - loss: 0.0477 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 68/200
# 1/1 - 0s - loss: 0.0455 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 69/200
# 1/1 - 0s - loss: 0.0435 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 70/200
# 1/1 - 0s - loss: 0.0416 - accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 71/200
# 1/1 - 0s - loss: 0.0398 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 72/200
# 1/1 - 0s - loss: 0.0382 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 73/200
# 1/1 - 0s - loss: 0.0366 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 74/200
# 1/1 - 0s - loss: 0.0352 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 75/200
# 1/1 - 0s - loss: 0.0338 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 76/200
# 1/1 - 0s - loss: 0.0325 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 77/200
# 1/1 - 0s - loss: 0.0313 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 78/200
# 1/1 - 0s - loss: 0.0302 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 79/200
# 1/1 - 0s - loss: 0.0291 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 80/200
# 1/1 - 0s - loss: 0.0281 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 81/200
# 1/1 - 0s - loss: 0.0271 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 82/200
# 1/1 - 0s - loss: 0.0262 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 83/200
# 1/1 - 0s - loss: 0.0254 - accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 84/200
# 1/1 - 0s - loss: 0.0246 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 85/200
# 1/1 - 0s - loss: 0.0238 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 86/200
# 1/1 - 0s - loss: 0.0231 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 87/200
# 1/1 - 0s - loss: 0.0224 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 88/200
# 1/1 - 0s - loss: 0.0217 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 89/200
# 1/1 - 0s - loss: 0.0211 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 90/200
# 1/1 - 0s - loss: 0.0205 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 91/200
# 1/1 - 0s - loss: 0.0199 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 92/200
# 1/1 - 0s - loss: 0.0194 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 93/200
# 1/1 - 0s - loss: 0.0189 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 94/200
# 1/1 - 0s - loss: 0.0184 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 95/200
# 1/1 - 0s - loss: 0.0179 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 96/200
# 1/1 - 0s - loss: 0.0175 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 97/200
# 1/1 - 0s - loss: 0.0170 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 98/200
# 1/1 - 0s - loss: 0.0166 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 99/200
# 1/1 - 0s - loss: 0.0162 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 100/200
# 1/1 - 0s - loss: 0.0159 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 101/200
# 1/1 - 0s - loss: 0.0155 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 102/200
# 1/1 - 0s - loss: 0.0151 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 103/200
# 1/1 - 0s - loss: 0.0148 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 104/200
# 1/1 - 0s - loss: 0.0145 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 105/200
# 1/1 - 0s - loss: 0.0142 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 106/200
# 1/1 - 0s - loss: 0.0139 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 107/200
# 1/1 - 0s - loss: 0.0136 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 108/200
# 1/1 - 0s - loss: 0.0133 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 109/200
# 1/1 - 0s - loss: 0.0130 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 110/200
# 1/1 - 0s - loss: 0.0128 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 111/200
# 1/1 - 0s - loss: 0.0125 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 112/200
# 1/1 - 0s - loss: 0.0123 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 113/200
# 1/1 - 0s - loss: 0.0121 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 114/200
# 1/1 - 0s - loss: 0.0118 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 115/200
# 1/1 - 0s - loss: 0.0116 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 116/200
# 1/1 - 0s - loss: 0.0114 - accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 117/200
# 1/1 - 0s - loss: 0.0112 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 118/200
# 1/1 - 0s - loss: 0.0110 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 119/200
# 1/1 - 0s - loss: 0.0108 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 120/200
# 1/1 - 0s - loss: 0.0106 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 121/200
# 1/1 - 0s - loss: 0.0104 - accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 122/200
# 1/1 - 0s - loss: 0.0103 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 123/200
# 1/1 - 0s - loss: 0.0101 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 124/200
# 1/1 - 0s - loss: 0.0099 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 125/200
# 1/1 - 0s - loss: 0.0098 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 126/200
# 1/1 - 0s - loss: 0.0096 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 127/200
# 1/1 - 0s - loss: 0.0094 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 128/200
# 1/1 - 0s - loss: 0.0093 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 129/200
# 1/1 - 0s - loss: 0.0091 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 130/200
# 1/1 - 0s - loss: 0.0090 - accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 131/200
# 1/1 - 0s - loss: 0.0089 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 132/200
# 1/1 - 0s - loss: 0.0087 - accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 133/200
# 1/1 - 0s - loss: 0.0086 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 134/200
# 1/1 - 0s - loss: 0.0085 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 135/200
# 1/1 - 0s - loss: 0.0083 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 136/200
# 1/1 - 0s - loss: 0.0082 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 137/200
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 138/200
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 139/200
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 140/200
# 1/1 - 0s - loss: 0.0078 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 141/200
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 142/200
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 143/200
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 144/200
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 145/200
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 146/200
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 147/200
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 148/200
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 149/200
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 150/200
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 151/200
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 152/200
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 153/200
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 154/200
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 155/200
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 156/200
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 157/200
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 158/200
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 159/200
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000 - 620us/epoch - 620us/step
# Epoch 160/200
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 161/200
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 162/200
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 163/200
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 164/200
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 165/200
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 166/200
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 167/200
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 168/200
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 169/200
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 170/200
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 171/200
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 172/200
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 173/200
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 174/200
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 175/200
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 176/200
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 177/200
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 178/200
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 179/200
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 180/200
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 181/200
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 182/200
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 183/200
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 184/200
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 185/200
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 186/200
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 187/200
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 188/200
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 189/200
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 190/200
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 191/200
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 192/200
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 193/200
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 194/200
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 195/200
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 196/200
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 197/200
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 198/200
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 199/200
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 200/200
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000 - 0s/epoch - 0s/step

# %%
# Generate text
def generate_text(model, seed_text, num_chars):
    for _ in range(num_chars):
        input_seq = [char_to_int[char] for char in seed_text]
        input_seq = np.reshape(input_seq, (1, len(input_seq), 1))
        input_seq = input_seq / float(len(chars))
        predicted = model.predict(input_seq, verbose=0)
        predicted_char = int_to_char[np.argmax(predicted)]
        seed_text += predicted_char
    return seed_text

# Generate 5 characters
print(generate_text(model, "hel", 5))
# Out:
# hellolol
